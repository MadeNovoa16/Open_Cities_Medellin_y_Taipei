# %%
ax.grid(False)

# %%
import matplotlib.pyplot as plt

# Crear el gráfico con escala logarítmica en el eje Y
fig, ax = plt.subplots(figsize=(12, 8))
df_grouped_sin_fabricacion.plot(kind='line', marker='o', ax=ax)

# Título y etiquetas
ax.set_title('Evolución de Ventas de Electricidad por Categoría', fontsize=16)
ax.set_xlabel('Año')
ax.set_ylabel('Ventas de Electricidad (escala logarítmica)')

# Escala logarítmica en Y
ax.set_yscale('log')

# Eliminar líneas de fondo (rejilla)
ax.grid(False)
for spine in ax.spines.values():
    spine.set_visible(False)

# Leyenda centrada abajo
ax.legend(title='Categoría de la Industria',
          loc='upper center', bbox_to_anchor=(0.5, -0.2),
          ncol=2, frameon=False)

plt.tight_layout()
plt.show()

# %%
# Filtrar para mostrar solo las primeras 10 categorías
categorias_a_mostrar = df_grouped_sin_fabricacion.columns[:10]  # Cambia 10 por el número que desees

# Filtrar el DataFrame para que contenga solo esas categorías
df_filtered = df_grouped_sin_fabricacion[categorias_a_mostrar]

# Crear el gráfico con escala logarítmica en el eje Y
fig, ax = plt.subplots(figsize=(12, 8))
df_filtered.plot(kind='line', marker='o', ax=ax)

# Título y etiquetas
ax.set_title('Evolución de Ventas de Electricidad por Categoría', fontsize=16)
ax.set_xlabel('Año')
ax.set_ylabel('Ventas de Electricidad (escala logarítmica)')

# Escala logarítmica en Y
ax.set_yscale('log')

# Eliminar líneas de fondo (rejilla)
ax.grid(False)
for spine in ax.spines.values():
    spine.set_visible(False)

# Leyenda centrada abajo
ax.legend(title='Categoría de la Industria',
          loc='upper center', bbox_to_anchor=(0.5, -0.2),
          ncol=2, frameon=False)

plt.tight_layout()
plt.show()
